# %%
import os
import shutil
import glob

# %% [markdown]
# # how 2 generate a new podcast
#
# - download all podcasts as mp3
#     - https://ddownr.com/
#     - https://www.youtube.com/playlist?list=PLSH_xM-KC3Zv3L2dLcX3WmtbQsfB8YSSw
# - convert to labelled text
#     - cut to <45 min long per podcast [cell 2]
#     - https://realpython.com/python-speech-recognition/

# %%
"ffmpeg -i ep13.mp3 -ss 00:00:00 -t 00:44:00 -c:v copy -c:a copy ../podcast_44min/44m_ep13.mp3"
#that does it. run it in powershell.
# Out:
# 'ffmpeg -i ep13.mp3 -ss 00:00:00 -t 00:44:00 -c:v copy -c:a copy ../podcast_44min/44m_ep13.mp3'
